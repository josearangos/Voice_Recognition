# %% [markdown]
# # Statics

# %% [markdown]
# Se crearan 3 funciones con el fin de extraer y ordenar los datos

# %% [markdown]
# get_nor_info lo que hace es organizar el DataFrame con los nombres de cada audio para extraer la información de la clase y el speaker, recibe el DataFrame unicamente con una columna con todo el nombre del archivo y retorna un DataFrame cuyas columnas son:
# "Class" que indica la clase
# "Speaker" que indica el hablante

# %%
import pandas as pd

# %%
def get_nor_info(text_dataFrame, header = 0):
    text_dataFrame[header], a = text_dataFrame[header].str.split(".",1).str
    text_dataFrame["Class"], text_dataFrame[header] = text_dataFrame[header].str.split("/",1).str
    text_dataFrame["Speaker"], text_dataFrame[header], text_dataFrame["Time"] = text_dataFrame[0].str.split("_",2).str
    text_dataFrame = text_dataFrame.drop([header], axis=1)
    return text_dataFrame

# %% [markdown]
# get_value_counts recibe el DataFrame organizado y retorna un Data Frame cuyas columnas son:
#    "Class" que indica el speaker
#    "Speaker" que indica el hablante
#    "Times" que indica las veces que ese hablante dijo es palabra

# %%
def get_value_counts(text_dataFrame):
    return text_dataFrame.groupby(["Class", "Speaker"]).size().reset_index(name="Times")

# %% [markdown]
# get_description recibe el dataFrame generado por get_value_counts y retorna un dataFrame con estadísticas básicas

# %%
def get_description(text_dataFrame):
    return text_dataFrame.groupby(["Class"]).describe()

# %% [markdown]
# ## Lo aplicamos al testing list

# %%
testing_list = get_nor_info(pd.read_csv("testing_list.txt", header = None))
testing_list
# Out:
#        Class   Speaker Time
# 0      right  bb05582b    3
# 1      right  97f4c236    2
# 2      right  f2e59fea    3
# 3      right  fdb5155e    2
# 4      right  dc75148d    0
# 5      right  3f170018    0
# 6      right  18f8afd5    3
# 7      right  e1469561    1
# 8      right  5c8af87a    0
# 9      right  aa48c94a    0
# 10     right  837a0f64    1
# 11     right  e49428d9    0
# 12     right  c7124b73    0
# 13     right  c7124b73    1
# 14     right  9d4bab4f    0
# 15     right  837a0f64    0
# 16     right  e49428d9    1
# 17     right  f0ae7203    2
# 18     right  aa80f517    4
# 19     right  aa48c94a    1
# 20     right  5c8af87a    1
# 21     right  e1469561    0
# 22     right  7257420c    0
# 23     right  18f8afd5    2
# 24     right  3f170018    1
# 25     right  f2e59fea    2
# 26     right  68dd409e    0
# 27     right  82d0d3ba    0
# 28     right  97f4c236    3
# 29     right  f428ca69    0
# ...      ...       ...  ...
# 10975   four  c22d3f18    4
# 10976   four  8fe67225    2
# 10977   four  189cbabe    3
# 10978   four  1b4c9b89    4
# 10979   four  b97c9f77    2
# 10980   four  f9643d42    3
# 10981   four  0cb74144    1
# 10982   four  d0faf7e4    1
# 10983   four  63f7a489    2
# 10984   four  f264e0df    0
# 10985   four  e0c782d5    0
# 10986   four  bfd26d6b    2
# 10987   four  b7e9f841    0
# 10988   four  b83c1acf    3
# 10989   four  b83c1acf    2
# 10990   four  47d01978    2
# 10991   four  bfd26d6b    3
# 10992   four  e0c782d5    1
# 10993   four  63f7a489    3
# 10994   four  d0faf7e4    0
# 10995   four  8494fba8    0
# 10996   four  0cb74144    0
# 10997   four  d5b963aa    2
# 10998   four  f9643d42    2
# 10999   four  b97c9f77    3
# 11000   four  189cbabe    2
# 11001   four  8fe67225    3
# 11002   four  c9e251d2    1
# 11003   four  0c40e715    0
# 11004   four  8769c34c    3
#
# [11005 rows x 3 columns]

# %%
testing_value_counts = get_value_counts(testing_list)
testing_value_counts
# Out:
#          Class   Speaker  Times
# 0     backward  03401e93      2
# 1     backward  0c540988      1
# 2     backward  0cb74144      4
# 3     backward  189cbabe      5
# 4     backward  18f8afd5      5
# 5     backward  1acc97de      4
# 6     backward  2005ca25      1
# 7     backward  3659fc1c      1
# 8     backward  3b4f8f24      5
# 9     backward  3d86b69a      4
# 10    backward  4c6167ca      2
# 11    backward  4fd1443e      5
# 12    backward  5170b77f      5
# 13    backward  5f01c798      2
# 14    backward  6379c6a2      1
# 15    backward  63f7a489      5
# 16    backward  837a0f64      3
# 17    backward  85d2ac4b      2
# 18    backward  87070229      4
# 19    backward  8769c34c      4
# 20    backward  893705bb      9
# 21    backward  8ea6dec6      1
# 22    backward  8fe67225      5
# 23    backward  91b03183      3
# 24    backward  a4383927      2
# 25    backward  a6f2fd71      5
# 26    backward  a7216980      5
# 27    backward  aa80f517      5
# 28    backward  bb05582b      5
# 29    backward  beb458a4      5
# ...        ...       ...    ...
# 4883      zero  d5b963aa      5
# 4884      zero  d7467392      2
# 4885      zero  d91a159e      1
# 4886      zero  d962e5ac      5
# 4887      zero  d9e9f554      1
# 4888      zero  daf230ac      2
# 4889      zero  db24628d      5
# 4890      zero  dc75148d      2
# 4891      zero  e0c782d5      4
# 4892      zero  e1469561      5
# 4893      zero  e41a903b      5
# 4894      zero  e49428d9      5
# 4895      zero  e5e54cee      1
# 4896      zero  e71b4ce6      2
# 4897      zero  e9901cf0      1
# 4898      zero  ea356919      1
# 4899      zero  ef2a3cfb      1
# 4900      zero  f264e0df      3
# 4901      zero  f292725f      1
# 4902      zero  f2e59fea      5
# 4903      zero  f5496439      1
# 4904      zero  f6af2457      1
# 4905      zero  f9643d42      5
# 4906      zero  fa446c16      1
# 4907      zero  fb7eb481      4
# 4908      zero  fce96bac      2
# 4909      zero  fdb5155e      2
# 4910      zero  fe1916ba      1
# 4911      zero  ffa76c4a      1
# 4912      zero  ffb86d3c      2
#
# [4913 rows x 3 columns]

# %%
get_description(testing_value_counts)
# Out:
#           Times
#           count      mean       std  min  25%  50%   75%   max
# Class
# backward   43.0  3.837209  1.660898  1.0  2.5  4.0  5.00   9.0
# bed       150.0  1.380000  0.720458  1.0  1.0  1.0  2.00   5.0
# bird      147.0  1.258503  0.537478  1.0  1.0  1.0  1.00   3.0
# cat       151.0  1.284768  0.558301  1.0  1.0  1.0  1.00   4.0
# dog       155.0  1.419355  0.728555  1.0  1.0  1.0  2.00   5.0
# down      165.0  2.460606  1.617349  1.0  1.0  2.0  4.00   8.0
# eight     153.0  2.666667  1.939886  1.0  1.0  2.0  4.00  14.0
# five      169.0  2.633136  1.798237  1.0  1.0  2.0  5.00  10.0
# follow     43.0  4.000000  1.889822  1.0  3.0  4.0  5.00  10.0
# forward    44.0  3.522727  1.704831  1.0  2.0  4.0  5.00   8.0
# four      160.0  2.500000  1.648327  1.0  1.0  2.0  4.00   9.0
# go        150.0  2.680000  1.796043  1.0  1.0  2.0  4.00  11.0
# happy     153.0  1.326797  0.647160  1.0  1.0  1.0  2.00   5.0
# house     148.0  1.290541  0.574437  1.0  1.0  1.0  1.25   5.0
# learn      49.0  3.285714  1.670828  1.0  1.0  4.0  5.00   6.0
# left      168.0  2.452381  1.666182  1.0  1.0  2.0  4.00   9.0
# marvin    150.0  1.300000  0.631925  1.0  1.0  1.0  1.00   4.0
# nine      163.0  2.503067  1.675437  1.0  1.0  2.0  4.00   8.0
# no        153.0  2.647059  1.886484  1.0  1.0  2.0  4.00  13.0
# off       166.0  2.421687  1.592562  1.0  1.0  2.0  4.00   7.0
# on        160.0  2.475000  1.873180  1.0  1.0  2.0  4.00  15.0
# one       158.0  2.525316  1.729104  1.0  1.0  2.0  4.00   9.0
# right     165.0  2.400000  1.568750  1.0  1.0  2.0  4.00   9.0
# seven     157.0  2.585987  1.739601  1.0  1.0  2.0  4.00   9.0
# sheila    152.0  1.394737  0.672624  1.0  1.0  1.0  2.00   4.0
# six       152.0  2.592105  1.731497  1.0  1.0  2.0  4.00   7.0
# stop      156.0  2.634615  2.254992  1.0  1.0  2.0  4.00  22.0
# three     170.0  2.382353  1.613822  1.0  1.0  2.0  3.75   9.0
# tree      131.0  1.473282  0.787677  1.0  1.0  1.0  2.00   4.0
# two       161.0  2.633540  1.829240  1.0  1.0  2.0  4.00  14.0
# up        157.0  2.707006  1.987980  1.0  1.0  2.0  4.00  17.0
# visual     49.0  3.367347  1.691817  1.0  1.0  4.0  5.00   6.0
# wow       147.0  1.401361  0.668876  1.0  1.0  1.0  2.00   4.0
# yes       162.0  2.586420  1.847090  1.0  1.0  2.0  4.75   9.0
# zero      156.0  2.679487  1.781580  1.0  1.0  2.0  4.00  10.0

# %% [markdown]
# ## Lo aplicamos a Training list

# %%
training_list = get_nor_info(pd.read_csv("training_list.txt", header = None))
training_list
# Out:
#           Class   Speaker Time
# 0      backward  0165e0e8    0
# 1      backward  017c4098    0
# 2      backward  017c4098    1
# 3      backward  017c4098    2
# 4      backward  017c4098    3
# 5      backward  017c4098    4
# 6      backward  02ade946    0
# 7      backward  02ade946    1
# 8      backward  02ade946    2
# 9      backward  02ade946    3
# 10     backward  02ade946    4
# 11     backward  042a8dde    0
# 12     backward  042a8dde    1
# 13     backward  042a8dde    2
# 14     backward  042a8dde    3
# 15     backward  050170cb    0
# 16     backward  050170cb    1
# 17     backward  050170cb    2
# 18     backward  050170cb    3
# 19     backward  050170cb    4
# 20     backward  0585b66d    0
# 21     backward  0585b66d    1
# 22     backward  0585b66d    2
# 23     backward  0585b66d    3
# 24     backward  0585b66d    4
# 25     backward  06f6c194    0
# 26     backward  06f6c194    1
# 27     backward  06f6c194    2
# 28     backward  06f6c194    3
# 29     backward  06f6c194    4
# ...         ...       ...  ...
# 84812      zero  fc3ba625    0
# 84813      zero  fc3ba625    1
# 84814      zero  fc3ba625    2
# 84815      zero  fc3ba625    3
# 84816      zero  fc3ba625    4
# 84817      zero  fcb25a78    0
# 84818      zero  fd5ccd39    0
# 84819      zero  fd5ccd39    1
# 84820      zero  fd5ccd39    2
# 84821      zero  fd5ccd39    3
# 84822      zero  fd9c7413    0
# 84823      zero  fe291fa9    0
# 84824      zero  fe31cb13    0
# 84825      zero  feb1d305    0
# 84826      zero  feb1d305    1
# 84827      zero  ff0e27c3    0
# 84828      zero  ff4ed4f3    0
# 84829      zero  ff4ed4f3    1
# 84830      zero  ff4ed4f3    2
# 84831      zero  ff63ab0b    0
# 84832      zero  ff63ab0b    1
# 84833      zero  ffbb695d    0
# 84834      zero  ffbb695d    1
# 84835      zero  ffbb695d    2
# 84836      zero  ffd2ba2f    0
# 84837      zero  ffd2ba2f    1
# 84838      zero  ffd2ba2f    2
# 84839      zero  ffd2ba2f    3
# 84840      zero  ffd2ba2f    4
# 84841      zero  fffcabd1    0
#
# [84842 rows x 3 columns]

# %%
training_value_counts = get_value_counts(training_list)
training_value_counts
# Out:
#           Class   Speaker  Times
# 0      backward  0165e0e8      1
# 1      backward  017c4098      5
# 2      backward  02ade946      5
# 3      backward  042a8dde      4
# 4      backward  050170cb      5
# 5      backward  0585b66d      5
# 6      backward  06f6c194      5
# 7      backward  08ab231c      5
# 8      backward  0a2b400e      5
# 9      backward  0a396ff2      1
# 10     backward  0a5636ca      1
# 11     backward  0b7ee1a0      5
# 12     backward  0ba018fc      4
# 13     backward  0d6d7360      5
# 14     backward  0d85a428      1
# 15     backward  0d90d8e1      4
# 16     backward  0e6e36c9      5
# 17     backward  0e8ec1cb      1
# 18     backward  0f46028a      5
# 19     backward  0f7266cf      4
# 20     backward  113b3fbc      5
# 21     backward  131e738d      5
# 22     backward  13a93b33      1
# 23     backward  13dce503      3
# 24     backward  1474273a      2
# 25     backward  1496195a      4
# 26     backward  14c7b073      5
# 27     backward  1589451d      2
# 28     backward  15dd287d      5
# 29     backward  18d84076      1
# ...         ...       ...    ...
# 39597      zero  f9f9751d      3
# 39598      zero  fa44fcf5      2
# 39599      zero  fa57ab3b      5
# 39600      zero  fac74f6a      1
# 39601      zero  facd97c0      2
# 39602      zero  fad7a69a      2
# 39603      zero  fb01a182      1
# 39604      zero  fb24c826      1
# 39605      zero  fb2f3242      2
# 39606      zero  fb727898      4
# 39607      zero  fb7c9b3b      1
# 39608      zero  fb8c31a9      6
# 39609      zero  fbb2f6cc      5
# 39610      zero  fbb56351      5
# 39611      zero  fbe51750      1
# 39612      zero  fbf3dd31      1
# 39613      zero  fc28c8d8      3
# 39614      zero  fc3ba625      5
# 39615      zero  fcb25a78      1
# 39616      zero  fd5ccd39      4
# 39617      zero  fd9c7413      1
# 39618      zero  fe291fa9      1
# 39619      zero  fe31cb13      1
# 39620      zero  feb1d305      2
# 39621      zero  ff0e27c3      1
# 39622      zero  ff4ed4f3      3
# 39623      zero  ff63ab0b      2
# 39624      zero  ffbb695d      3
# 39625      zero  ffd2ba2f      5
# 39626      zero  fffcabd1      1
#
# [39627 rows x 3 columns]

# %%
get_description(training_value_counts)
# Out:
#            Times
#            count      mean       std  min  25%  50%  75%   max
# Class
# backward   376.0  3.579787  2.053684  1.0  2.0  4.0  5.0  23.0
# bed       1152.0  1.383681  0.677562  1.0  1.0  1.0  2.0   6.0
# 16    right  409c962a    0
# 17    right  439c84f4    0
# 18    right  48bfde8e    2
# 19    right  439c84f4    2
# 20    right  48bfde8e    0
# 21    right  6d818f6c    1
# 22    right  dbaf8fc6    1
# 23    right  a6d586b7    2
# 24    right  6c88cf25    0
# 25    right  8b775397    0
# 26    right  7fd25f7c    1
# 27    right  65ec06e5    0
# 28    right  ff2b842e    0
# 29    right  827421c4    0
# ...     ...       ...  ...
# 9951   four  099d52ad    0
# 9952   four  541120c7    0
# 9953   four  31f01a8d    3
# 9954   four  ad63d93c    3
# 9955   four  3c4aa5ef    0
# 9956   four  d3831f6a    2
# 9957   four  b5eb4f9b    1
# 9958   four  d3831f6a    0
# 9959   four  3c4aa5ef    2
# 9960   four  ad63d93c    1
# 9961   four  31f01a8d    1
# 9962   four  099d52ad    2
# 9963   four  dca2797e    4
# 9964   four  6d0ad764    0
# 9965   four  50f55535    0
# 9966   four  bfbd0e6b    1
# 9967   four  32ad5b65    0
# 9968   four  32ad5b65    1
# 9969   four  638685f2    0
# 9970   four  bfbd0e6b    0
# 9971   four  6d0ad764    1
# 9972   four  538e1856    0
# 9973   four  67c7fecb    0
# 9974   four  099d52ad    3
# 9975   four  31f01a8d    0
# 9976   four  d107dc42    0
# 9977   four  ad63d93c    0
# 9978   four  d3831f6a    1
# 9979   four  3c4aa5ef    3
# 9980   four  c6389ab0    0
#
# [9981 rows x 3 columns]

# %%
validation_value_counts = get_value_counts(training_list)
validation_value_counts
# Out:
#           Class   Speaker  Times
# 0      backward  0165e0e8      1
# 1      backward  017c4098      5
# 2      backward  02ade946      5
# 3      backward  042a8dde      4
# 4      backward  050170cb      5
# 5      backward  0585b66d      5
# 6      backward  06f6c194      5
# 7      backward  08ab231c      5
# 8      backward  0a2b400e      5
# 9      backward  0a396ff2      1
# 10     backward  0a5636ca      1
# 11     backward  0b7ee1a0      5
# 12     backward  0ba018fc      4
# 13     backward  0d6d7360      5
# 14     backward  0d85a428      1
# 15     backward  0d90d8e1      4
# 16     backward  0e6e36c9      5
# 17     backward  0e8ec1cb      1
# 18     backward  0f46028a      5
# 19     backward  0f7266cf      4
# 20     backward  113b3fbc      5
# 21     backward  131e738d      5
# 22     backward  13a93b33      1
# 23     backward  13dce503      3
# 24     backward  1474273a      2
# 25     backward  1496195a      4
# 26     backward  14c7b073      5
# 27     backward  1589451d      2
# 28     backward  15dd287d      5
# 29     backward  18d84076      1
# ...         ...       ...    ...
# 39597      zero  f9f9751d      3
# 39598      zero  fa44fcf5      2
# 39599      zero  fa57ab3b      5
# 39600      zero  fac74f6a      1
# 39601      zero  facd97c0      2
# 39602      zero  fad7a69a      2
# 39603      zero  fb01a182      1
# 39604      zero  fb24c826      1
# 39605      zero  fb2f3242      2
# 39606      zero  fb727898      4
# 39607      zero  fb7c9b3b      1
# 39608      zero  fb8c31a9      6
# 39609      zero  fbb2f6cc      5
# 39610      zero  fbb56351      5
# 39611      zero  fbe51750      1
# 39612      zero  fbf3dd31      1
# 39613      zero  fc28c8d8      3
# 39614      zero  fc3ba625      5
# 39615      zero  fcb25a78      1
# 39616      zero  fd5ccd39      4
