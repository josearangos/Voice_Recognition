# %%
import pandas as pd
import numpy as np
from skimage import io

# %%
df = pd.read_hdf('/home/josearangos/Documentos/Projects/Voice_Recognition/data/spectrograms/descriptions_5_class.hd5')

# %%
df
# Out:
#                                                     path   speaker  word
# 0      /home/josearangos/Documentos/Projects/Voice_Re...  004ae714   yes
# 1      /home/josearangos/Documentos/Projects/Voice_Re...  004ae714   yes
# 2      /home/josearangos/Documentos/Projects/Voice_Re...  00970ce1   yes
# 3      /home/josearangos/Documentos/Projects/Voice_Re...  00f0204f   yes
# 4      /home/josearangos/Documentos/Projects/Voice_Re...  00f0204f   yes
# ...                                                  ...       ...   ...
# 14995  /home/josearangos/Documentos/Projects/Voice_Re...  f2898d06  nine
# 14996  /home/josearangos/Documentos/Projects/Voice_Re...  f2898d06  nine
# 14997  /home/josearangos/Documentos/Projects/Voice_Re...  f2b8fc18  nine
# 14998  /home/josearangos/Documentos/Projects/Voice_Re...  f2e9b610  nine
# 14999  /home/josearangos/Documentos/Projects/Voice_Re...  f2e9b610  nine
#
# [15000 rows x 3 columns]

# %%
im = io.imread(df.iloc[0,0])

# %%
im.shape
# Out:
# (99, 161, 3)

# %%
help(im)
# Out:
# Help on JpegImageFile in module PIL.JpegImagePlugin object:
#
# class JpegImageFile(PIL.ImageFile.ImageFile)
#  |  JpegImageFile(fp=None, filename=None)
#  |
#  |  Base class for image file format handlers.
#  |
#  |  Method resolution order:
#  |      JpegImageFile
#  |      PIL.ImageFile.ImageFile
#  |      PIL.Image.Image
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  draft(self, mode, size)
#  |      Configures the image file loader so it returns a version of the
#  |      image that as closely as possible matches the given mode and
#  |      size. For example, you can use this method to convert a color
#  |      JPEG to greyscale while loading it.
#  |
#  |      If any changes are made, returns a tuple with the chosen ``mode`` and
#  |      ``box`` with coordinates of the original image within the altered one.
#  |
#  |      Note that this method modifies the :py:class:`~PIL.Image.Image` object
# ...

# %%
im.size
# Out:
# (960, 960)

# %%
np.array(list(im.getdata())).shape
# Out:
# (921600, 3)
